# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunjung-Cho/Project/blob/master/%EA%B0%9C%EC%9D%B8/%ED%8A%B8%EB%A0%8C%EB%93%9C/sales_fake_%EC%83%9D%EC%84%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv("/content/sales_fake.csv")

# %%
df
# Out:
#       brand category1 category2  product_id  \
# 0        K2       아우터      일반자켓  KWM23142KF
# 1        K2       아우터    바람막이자켓  KWM23124P1
# 2        K2       아우터      방수자켓  KMP23113JY
# 3        K2       아우터       베스트  KMM236132C
# 4        K2       아우터    트레이닝상의  KWM23134Z1
# 5        K2       아우터      일반자켓  KMM23141K7
# 6        K2       아우터    바람막이자켓  KMM231231A
# 7        K2       아우터      방수자켓  KMP231035B
# 8        K2       아우터       베스트  KMM236172C
# 9        K2       아우터    트레이닝상의  KMM231091A
# 10       K2       아우터        패딩  GMW22571JU
# 11       K2       아우터        다운  KUW21599W6
# 12    Eider       아우터        다운  DMP23541W4
# 13    Eider       아우터        패딩  DMP23111C2
# 14    Eider       아우터        자켓  DUP23152W4
# 15    Eider       아우터     방풍 자켓  DMM23102B1
# 16    Eider       아우터      방수자켓  DMP23731K7
# 17    Eider       아우터    트레이닝상의  DMP23102C2
# 18    Eider       아우터       베스트  DMM23601C3
# 19    Eider       아우터        다운  DMP23543C3
# ...

# %%
# sales_date 열 추가
start_date = pd.to_datetime("2021-01-01")
end_date = pd.to_datetime("2023-05-31")
date_range = pd.date_range(start_date, end_date, freq='D')

# %%
# product_id를 기준으로 행을 확장하여 sales_date 할당
expanded_rows = []
for index, row in df.iterrows():
    product_id = row['product_id']
    product_dates = date_range.tolist()
    expanded_rows.extend([(product_id, date) for date in product_dates])

expanded_df = pd.DataFrame(expanded_rows, columns=['product_id', 'sales_date'])
df = df.merge(expanded_df, on='product_id', how='left')

# %%
filtered_df = df[df['product_id'] == 'KWM23142KF']
filtered_df
# Out:
#     brand category1 category2  product_id  \
# 0      K2       아우터      일반자켓  KWM23142KF
# 1      K2       아우터      일반자켓  KWM23142KF
# 2      K2       아우터      일반자켓  KWM23142KF
# 3      K2       아우터      일반자켓  KWM23142KF
# 4      K2       아우터      일반자켓  KWM23142KF
# ..    ...       ...       ...         ...
# 876    K2       아우터      일반자켓  KWM23142KF
# 877    K2       아우터      일반자켓  KWM23142KF
# 878    K2       아우터      일반자켓  KWM23142KF
# 879    K2       아우터      일반자켓  KWM23142KF
# 880    K2       아우터      일반자켓  KWM23142KF
#
#                             product_name product_price sales_date
# 0    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-01
# 1    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-02
# 2    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-03
# 3    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-04
# 4    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-05
# ...

# %%
df.columns
# Out:
# Index(['brand', 'category1', 'category2', 'product_id', 'product_name',
#        'product_price', 'sales_date'],
#       dtype='object')

# %%
df['category2'].unique()
# Out:
# array(['일반자켓', '바람막이자켓', '방수자켓', '베스트', '트레이닝상의', '패딩', '다운', '자켓',
#        '방풍 자켓', '바람막이/아노락', '자켓/가디건', '긴바지', '조거', '트레이닝하의', '반바지', '레깅스',
#        '스커트', '래쉬가드하의'], dtype=object)

# %%
# 조건에 따라 sales_qt 값을 설정하는 함수
def set_sales_qt(row):
    sales_date = row['sales_date']
    year = sales_date.year
    month = sales_date.month
    category2 = row['category2']

    if year == 2021:
        # 2021년도에 해당하는 조건 추가
        if month in [11, 12, 1] and category2 in ['패딩', '다운']:
            return random.randint(30, 40)
        elif month in [11, 12, 1] and category2 in ['베스트', '슬림다운']:
            return random.randint(20, 30)
        elif month in [11, 12, 1] and '자켓' in category2:
            return random.randint(10, 20)
        elif month in [10, 2] and category2 in ['패딩', '다운']:
            return random.randint(10, 20)
        elif month in [10, 2] and category2 in ['베스트', '슬림다운']:
            return random.randint(10, 20)
        elif month in [10, 2] and '자켓' in category2:
            return random.randint(20, 40)
        elif month in [3, 9] and category2 in ['패딩', '다운']:
            return random.randint(1, 10)
        elif month in [3, 9] and category2 in ['베스트', '슬림다운']:
            return random.randint(5, 15)
        elif month in [3, 9] and '자켓' in category2:
            return random.randint(30, 40)
        elif month in [4, 5, 8] and category2 in ['패딩', '다운']:
            return random.randint(1, 5)
        elif month in [4, 5, 8] and category2 in ['베스트', '슬림다운']:
            return random.randint(1, 5)
        elif month in [4, 5, 8] and '자켓' in category2:
            return random.randint(5, 15)
        elif month in [6, 7] and category2 in ['패딩', '다운']:
            return random.randint(1, 5)
        elif month in [6, 7] and category2 in ['베스트', '슬림다운']:
            return random.randint(1, 5)
        elif month in [6, 7] and '자켓' in category2:
            return random.randint(5, 15)
        elif month in [6, 7, 8] and '래쉬가드하의' in category2:
            return random.randint(20, 30)
        elif month in [6, 7, 8] and '반바지' in category2:
          return random.randint(50, 60)
        elif month in [11, 12, 1, 2] and '반바지' in category2:
          return random.randint(15, 25)
        elif month in [11, 12, 1, 2] and '래쉬가드하의' in category2:
          return random.randint(1, 5)
        elif month in [11, 12, 1, 2] and '스커트' in category2:
          return random.randint(1, 10)
        elif month in [3, 4, 5, 9, 10] and '반바지' in category2:
          return random.randint(25, 45)
        elif month in [3, 4, 5, 9, 10] and '래쉬가드하의' in category2:
          return random.randint(5, 10)
        elif month in [3,4,5,9,10] and '스커트' in category2:
          return random.randint(15, 25)
        elif category2 in ['긴바지', '레깅스', '트레이닝하의', '조거']:
          return random.randint(15, 35)
        else:
            return random.randint(5, 15)

    if year == 2022:
        # 2021년도에 해당하는 조건 추가
        if month in [11, 12, 1] and category2 in ['패딩', '다운']:
            return random.randint(30, 40) * 1.06
        elif month in [11, 12, 1] and category2 in ['베스트', '슬림다운']:
            return random.randint(20, 30) * 1.06
        elif month in [11, 12, 1] and '자켓' in category2:
            return random.randint(10, 20) * 1.06
        elif month in [10, 2] and category2 in ['패딩', '다운']:
            return random.randint(10, 20) * 1.06
        elif month in [10, 2] and category2 in ['베스트', '슬림다운']:
            return random.randint(10, 20) * 1.06
        elif month in [10, 2] and '자켓' in category2:
            return random.randint(20, 40) * 1.06
        elif month in [3, 9] and category2 in ['패딩', '다운']:
            return random.randint(1, 10) * 1.06
        elif month in [3, 9] and category2 in ['베스트', '슬림다운']:
            return random.randint(5, 15) * 1.06
        elif month in [3, 9] and '자켓' in category2:
            return random.randint(30, 40) * 1.06
        elif month in [4, 5, 8] and category2 in ['패딩', '다운']:
            return random.randint(1, 5) * 1.06
        elif month in [4, 5, 8] and category2 in ['베스트', '슬림다운']:
            return random.randint(1, 5) * 1.06
        elif month in [4, 5, 8] and '자켓' in category2:
            return random.randint(5, 15) * 1.06
        elif month in [6, 7] and category2 in ['패딩', '다운']:
            return random.randint(1, 5) * 1.06
        elif month in [6, 7] and category2 in ['베스트', '슬림다운']:
            return random.randint(1, 5) * 1.06
        elif month in [6, 7] and '자켓' in category2:
            return random.randint(5, 15) * 1.06
        elif month in [6, 7, 8] and '래쉬가드하의' in category2:
          return random.randint(20, 30) * 1.03
        elif month in [6, 7, 8] and '반바지' in category2:
          return random.randint(50, 60) * 1.03
        elif month in [11, 12, 1, 2] and '반바지' in category2:
          return random.randint(15, 25) * 1.03
        elif month in [11, 12, 1, 2] and '래쉬가드하의' in category2:
          return random.randint(1, 5) * 1.03
        elif month in [11, 12, 1, 2] and '스커트' in category2:
          return random.randint(1, 10) * 1.03
        elif month in [3, 4, 5, 9, 10] and '반바지' in category2:
          return random.randint(25, 45) * 1.03
        elif month in [3, 4, 5, 9, 10] and '래쉬가드하의' in category2:
          return random.randint(5, 10) * 1.03
        elif month in [3,4,5,9,10] and '스커트' in category2:
          return random.randint(15, 25) * 1.03
        elif category2 in ['긴바지', '레깅스', '트레이닝하의', '조거']:
          return random.randint(15, 35) * 1.03
        else:
            return random.randint(5, 15) * 1.06

    if year == 2023:
        # 2021년도에 해당하는 조건 추가
        if month in [11, 12, 1] and category2 in ['패딩', '다운']:
            return random.randint(30, 40) * 1.06 * 1.3
        elif month in [11, 12, 1] and category2 in ['베스트', '슬림다운']:
            return random.randint(20, 30) * 1.06 * 1.3
        elif month in [11, 12, 1] and '자켓' in category2:
            return random.randint(10, 20) * 1.06 * 1.3
        elif month in [10, 2] and category2 in ['패딩', '다운']:
            return random.randint(10, 20) * 1.06 * 1.3
        elif month in [10, 2] and category2 in ['베스트', '슬림다운']:
            return random.randint(10, 20) * 1.06 * 1.3
        elif month in [10, 2] and '자켓' in category2:
            return random.randint(20, 40) * 1.06 * 1.3
        elif month in [3, 9] and category2 in ['패딩', '다운']:
            return random.randint(1, 10) * 1.06 * 1.3
        elif month in [3, 9] and category2 in ['베스트', '슬림다운']:
            return random.randint(5, 15) * 1.06 * 1.3
        elif month in [3, 9] and '자켓' in category2:
            return random.randint(30, 40) * 1.06 * 1.3
        elif month in [4, 5, 8] and category2 in ['패딩', '다운']:
            return random.randint(1, 5) * 1.06 * 1.3
        elif month in [4, 5, 8] and category2 in ['베스트', '슬림다운']:
            return random.randint(1, 5) * 1.06 * 1.3
        elif month in [4, 5, 8] and '자켓' in category2:
            return random.randint(5, 15) * 1.06 * 1.3
        elif month in [6, 7] and category2 in ['패딩', '다운']:
            return random.randint(1, 5) * 1.06 * 1.3
        elif month in [6, 7] and category2 in ['베스트', '슬림다운']:
            return random.randint(1, 5) * 1.06 * 1.3
        elif month in [6, 7] and '자켓' in category2:
            return random.randint(5, 15) * 1.06 * 1.3
        elif month in [6, 7, 8] and '래쉬가드하의' in category2:
          return random.randint(20, 30) * 1.03 * 1.2
        elif month in [6, 7, 8] and '반바지' in category2:
          return random.randint(50, 60) * 1.03 * 1.2
        elif month in [11, 12, 1, 2] and '반바지' in category2:
          return random.randint(15, 25) * 1.03 * 1.2
        elif month in [11, 12, 1, 2] and '래쉬가드하의' in category2:
          return random.randint(1, 5) * 1.03 * 1.2
        elif month in [11, 12, 1, 2] and '스커트' in category2:
          return random.randint(1, 10) * 1.03 * 1.2
        elif month in [3, 4, 5, 9, 10] and '반바지' in category2:
          return random.randint(25, 45) * 1.03 * 1.2
        elif month in [3, 4, 5, 9, 10] and '래쉬가드하의' in category2:
          return random.randint(5, 10) * 1.03 * 1.2
        elif month in [3,4,5,9,10] and '스커트' in category2:
          return random.randint(15, 25) * 1.03 * 1.2
        elif category2 in ['긴바지', '레깅스', '트레이닝하의', '조거']:
          return random.randint(15, 35) * 1.03 * 1.2
        else:
            return random.randint(5, 15) * 1.06 * 1.3


# sales_qt 값을 설정하기 위해 apply 함수를 사용하여 각 행에 함수를 적용
df['sales_qt'] = df.apply(set_sales_qt, axis=1)

# %%
df
# Out:
#          brand category1 category2  product_id  \
# 0           K2       아우터      일반자켓  KWM23142KF
# 1           K2       아우터      일반자켓  KWM23142KF
# 2           K2       아우터      일반자켓  KWM23142KF
# 3           K2       아우터      일반자켓  KWM23142KF
# 4           K2       아우터      일반자켓  KWM23142KF
# ...        ...       ...       ...         ...
# 44045  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44046  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44047  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44048  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44049  Dynafit        하의    래쉬가드하의  YWM23390Z1
#
#                               product_name  product_price sales_date  \
# 0      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-01
# 1      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-02
# 2      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-03
# 3      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-04
# ...

# %%
df_2021 = df[df['sales_date'].dt.year == 2021]
df_2021
# Out:
#          brand category1 category2  product_id  \
# 0           K2       아우터      일반자켓  KWM23142KF
# 1           K2       아우터      일반자켓  KWM23142KF
# 2           K2       아우터      일반자켓  KWM23142KF
# 3           K2       아우터      일반자켓  KWM23142KF
# 4           K2       아우터      일반자켓  KWM23142KF
# ...        ...       ...       ...         ...
# 43529  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43530  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43531  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43532  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43533  Dynafit        하의    래쉬가드하의  YWM23390Z1
#
#                               product_name product_price sales_date  sales_qt
# 0      플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-01      11.0
# 1      플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-02      15.0
# 2      플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-03      11.0
# 3      플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2021-01-04      13.0
# ...

# %%
import plotly.express as px

df['sales_date'] = pd.to_datetime(df['sales_date'])

df['year_month'] = df['sales_date'].dt.to_period('M').astype(str)


fig = px.bar(df, x='year_month', y='sales_qt', labels={'year_month': 'Year-Month', 'sales_qt': 'Sales Quantity'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
total_sales_2021 = df[df['sales_date'].dt.year == 2021]['sales_qt'].sum()
total_sales_2021
# Out:
# 304353.0

# %%
total_sales_2021_1 = df[(df['sales_date'].dt.year == 2021) & (df['sales_date'].dt.month == 1)]['sales_qt'].sum()
total_sales_2021_1
# Out:
# 29924.0

# %%
total_sales_2022 = df[df['sales_date'].dt.year == 2022]['sales_qt'].sum()
total_sales_2022
# Out:
# 322506.06

# %%
total_sales_2022_1 = df[(df['sales_date'].dt.year == 2022) & (df['sales_date'].dt.month == 1)]['sales_qt'].sum()
total_sales_2022_1
# Out:
# 31839.22

# %%
total_sales_2023 = df[df['sales_date'].dt.year == 2023]['sales_qt'].sum()
total_sales_2023
# Out:
# 170826.526

# %%
total_sales_2023_1 = df[(df['sales_date'].dt.year == 2023) & (df['sales_date'].dt.month == 1)]['sales_qt'].sum()
total_sales_2023_1
# Out:
# 41368.938

# %%
(total_sales_2022 - total_sales_2021) / total_sales_2021
# Out:
# 0.05964475461060018

# %%
(total_sales_2023_1 - total_sales_2022_1) / total_sales_2022_1
# Out:
# 0.2993075207244399

# %%
df_2022 = df[df['sales_date'].dt.year == 2022]
df_2022
# Out:
#          brand category1 category2  product_id  \
# 365         K2       아우터      일반자켓  KWM23142KF
# 366         K2       아우터      일반자켓  KWM23142KF
# 367         K2       아우터      일반자켓  KWM23142KF
# 368         K2       아우터      일반자켓  KWM23142KF
# 369         K2       아우터      일반자켓  KWM23142KF
# ...        ...       ...       ...         ...
# 43894  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43895  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43896  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43897  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 43898  Dynafit        하의    래쉬가드하의  YWM23390Z1
#
#                               product_name product_price sales_date  sales_qt  \
# 365    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2022-01-01     12.72
# 366    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2022-01-02     12.72
# 367    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2022-01-03     19.08
# 368    플라이슈트(FLYSUIT) OUNCE W (Misty mint)       179,000 2022-01-04     19.08
# ...

# %%
# product_price 컬럼의 값에서 쉼표(,) 제거 및 int로 변환
df['product_price'] = df['product_price'].str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-9f8c46616d76> in <cell line: 2>()
#       1 # product_price 컬럼의 값에서 쉼표(,) 제거 및 int로 변환
# ----> 2 df['product_price'] = df['product_price'].str.replace(',', '').astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
# ...

# %%
# sales_price 계산하여 새로운 컬럼 추가
df['sales_revenue'] = df['product_price'] * df['sales_qt']

# %%
df = df.drop('sales_price', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-a9703a612cef> in <cell line: 1>()
# ----> 1 df = df.drop('sales_price', axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df
# Out:
#          brand category1 category2  product_id  \
# 0           K2       아우터      일반자켓  KWM23142KF
# 1           K2       아우터      일반자켓  KWM23142KF
# 2           K2       아우터      일반자켓  KWM23142KF
# 3           K2       아우터      일반자켓  KWM23142KF
# 4           K2       아우터      일반자켓  KWM23142KF
# ...        ...       ...       ...         ...
# 44045  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44046  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44047  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44048  Dynafit        하의    래쉬가드하의  YWM23390Z1
# 44049  Dynafit        하의    래쉬가드하의  YWM23390Z1
#
#                               product_name  product_price sales_date  \
# 0      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-01
# 1      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-02
# 2      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-03
# 3      플라이슈트(FLYSUIT) OUNCE W (Misty mint)         179000 2021-01-04
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.4/27.4 MB 37.1 MB/s eta 0:00:00
# ...

# %%
import mysql.connector
from sqlalchemy import create_engine

# %%
# 데이터베이스 연결 설정
config = {
    'user': 'ft',
    'password': 'brackets2021',
    'host': '34.134.49.231',
    'port': 3306,
    'database': 'ft'
}

# MySQL 서버에 연결
cnx = mysql.connector.connect(**config)

# SQLAlchemy 엔진 생성
engine = create_engine('mysql+mysqlconnector://ft:brackets2021@34.134.49.231:3306/ft')

# %%
df.columns
# Out:
# Index(['brand', 'category1', 'category2', 'product_id', 'product_name',
#        'product_price', 'sales_date', 'sales_qt', 'year_month',
#        'sales_revenue'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44050 entries, 0 to 44049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          44050 non-null  object
#  1   category1      44050 non-null  object
#  2   category2      44050 non-null  object
#  3   product_id     44050 non-null  object
#  4   product_name   44050 non-null  object
#  5   product_price  44050 non-null  int64
#  6   sales_date     44050 non-null  datetime64[ns]
#  7   sales_qt       44050 non-null  float64
#  8   year_month     44050 non-null  object
#  9   sales_revenue  44050 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 3.7+ MB

# %%
df['sales_qt'] = df['sales_qt'].astype(int)
df['sales_revenue'] = df['sales_revenue'].astype(int)

# %%
# df 데이터프레임을 MySQL에 테이블로 쓰기
df.to_sql(name='sales_fake', con=engine, if_exists='replace', index=False)

# 연결 닫기
cnx.close()
