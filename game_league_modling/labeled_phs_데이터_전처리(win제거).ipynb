# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunjung-Cho/Project/blob/master/labeled_phs_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%84%EC%B2%98%EB%A6%AC(win%EC%A0%9C%EA%B1%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 필요한 열만
#
# - 사용한 데이터: labeled_phs
#
# --- 사용할 열 이름 ---
#
# < 기존에 이미 있는 열들 >
#
# Eliminations  (처치)
# Final Blows  (막타)
# Healing Received (힐 받은 량)
# Damage Blocked (데미지 막은 횟수)
# Damage Taken (데미지 입은 량)
# Ultimates Earned - Fractional (궁극기 모으기)
# Ultimates Negated (궁극기 무효화)
# Ultimates Used (궁극기 사용횟수)
# Time Played (게임 시간)
# Assists (도움)
# Defensive Assists(공격형도움 -> 힐러들만 있는 스탯)
# Offensive Assists(방어형도움 -> 힐러들만 있는 스탯)
#
# < 합쳐서 추가한 열들>
# Damage  ( 데미지 가한 총량)
# Healing  (힐을한 총량)
# Kill  (킬 총량)
# Death  (죽음 총량)
# Barrier  (상대 데미지 막은 총량)
#
#
# -> feature 수: 총 17개
#
# Damage, Healing, Kill, Death, Barrier, Eliminations, Final Blows, Healing Received, Damage Blocked, Damage Taken, Ultimates Earned - Fractional, Ultimates Negated, Ultimates Used, Time Played , Assists, Defensive Assists, Offensive Assists

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/개인프로젝트/labeled_phs_2.csv")
df.head()
# Out:
#    esports_match_id              map_name  ... of Rockets Fired  win
# 0             30991           Eichenwalde  ...              NaN    0
# 1             30991           Eichenwalde  ...              NaN    1
# 2             30991                Havana  ...              NaN    0
# 3             30991                Havana  ...              NaN    1
# 4             30991  Horizon Lunar Colony  ...              NaN    0
#
# [5 rows x 363 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246 entries, 0 to 2245
# Columns: 363 entries, esports_match_id to win
# dtypes: float64(350), int64(11), object(2)
# memory usage: 6.2+ MB

# %%
sum(df.isnull().sum() == 0)
# Out:
# 32

# %%
df['win'].isnull().sum()
# Out:
# 0

# %%
df = df.fillna(0)
df
# Out:
#       esports_match_id              map_name  ... of Rockets Fired  win
# 0                30991           Eichenwalde  ...         0.000000    0
# 1                30991           Eichenwalde  ...         0.000000    1
# 2                30991                Havana  ...         0.000000    0
# 3                30991                Havana  ...         0.000000    1
# 4                30991  Horizon Lunar Colony  ...         0.000000    0
# ...                ...                   ...  ...              ...  ...
# 2241             35554                 Busan  ...         0.000000    1
# 2242             35554            King's Row  ...         0.000000    0
# 2243             35554            King's Row  ...         0.000000    1
# 2244             35554      Temple of Anubis  ...         0.000000    0
# 2245             35554      Temple of Anubis  ...         0.097561    1
#
# [2246 rows x 363 columns]

# %%
list1 = df.columns.tolist()
print(list1)
# Out:
# ['esports_match_id', 'map_name', 'team_name', 'Ability Damage Done', 'Accretion Kills', 'Accretion Stuns', 'Adaptive Shield Uses', 'Air Uptime', 'Air Uptime Percentage', 'All Damage Done', 'Amped Heal Activations', 'Amped Speed Activations', 'Amplification Matrix Assists', 'Amplification Matrix Casts', 'Amplification Matrix Efficiency', 'Armor - Rally', 'Armor - Repair Pack', 'Armor Provided', 'Assists', 'Average Energy', 'Average Players per Teleporter', 'Average Time Alive', 'Barrage Efficiency', 'Barrage Kills', 'Barrier Damage Done', 'Biotic Field Healing Done', 'Biotic Fields Deployed', 'Biotic Grenade Kills', 'Biotic Launcher Healing Explosions', 'Biotic Launcher Healing Shots', 'Biotic Orb Damage Efficiency', 'Biotic Orb Healing Efficiency', 'Biotic Orb Maximum Damage', 'Biotic Orb Maximum Healing', 'Blaster Kills', 'Blizzard Efficiency', 'Blizzard Kills', 'Bob Gun Damage', 'Bob Kills', 'Charge Kills', 'Coach Gun Kills', 'Coalescence Healing', 'Coalescence Kills', 'Coalesence 
# ...

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# * 한번에 합칠려고 시도해본것

# %%
df['B'] = [sum(x[0]) for x in df.values.tolist()]

# %%
df['damage'] = df[sum(s[0] for s in df.columns]

# %% [markdown]
# ### 데미지 열

# %%
Damage = []
for s in list1:
    if "Damage" in s:
       Damage.append(s)

# %%
print(Damage)
# Out:
# ['Ability Damage Done', 'All Damage Done', 'Barrier Damage Done', 'Biotic Orb Damage Efficiency', 'Biotic Orb Maximum Damage', 'Bob Gun Damage', 'Coalesence - Damage per Use', 'Damage - Accretion', 'Damage - Barrage', 'Damage - Biotic Grenade', 'Damage - Biotic Orb', 'Damage - Blizzard', 'Damage - Bob', 'Damage - Bob Charge', 'Damage - Boosters', 'Damage - Call Mech', 'Damage - Chain Hook', 'Damage - Charge', 'Damage - Coach Gun', 'Damage - Coalescence', 'Damage - Concussion Mine', 'Damage - Deadeye', 'Damage - Death Blossom', 'Damage - Deflect', 'Damage - Discord Orb', 'Damage - Dragonblade', 'Damage - Dragonblade Total', 'Damage - Dragonstrike', 'Damage - Duplicate', 'Damage - Dynamite', 'Damage - EMP', 'Damage - Earthshatter', 'Damage - Fire Strike', 'Damage - Flashbang', 'Damage - Focusing Beam', 'Damage - Focusing Beam - Bonus Damage Only', 'Damage - Grappling Claw', 'Damage - Graviton Surge', 'Damage - Helix Rockets', 'Damage - Hyperspheres', 'Damage - Jump Pack', 'Damage - Met
# ...

# %%
len(Damage)
# Out:
# 97

# %%
df["Damage"] = df['Ability Damage Done']+df[ 'All Damage Done']+df[ 'Barrier Damage Done']+df[ 'Biotic Orb Damage Efficiency']+df[ 'Biotic Orb Maximum Damage']+df[ 'Bob Gun Damage']+df[ 'Coalesence - Damage per Use']+df[ 'Damage - Accretion']+df[ 'Damage - Barrage']+df[ 'Damage - Biotic Grenade']+df[ 'Damage - Biotic Orb']+df[ 'Damage - Blizzard']+df[ 'Damage - Bob']+df[ 'Damage - Bob Charge']+df[ 'Damage - Boosters']+df[ 'Damage - Call Mech']+df[ 'Damage - Chain Hook']+df[ 'Damage - Charge']+df[ 'Damage - Coach Gun']+df[ 'Damage - Coalescence']+df[ 'Damage - Concussion Mine']+df[ 'Damage - Deadeye']+df[ 'Damage - Death Blossom']+df[ 'Damage - Deflect']+df[ 'Damage - Discord Orb']+df[ 'Damage - Dragonblade']+df[ 'Damage - Dragonblade Total']+df[ 'Damage - Dragonstrike']+df[ 'Damage - Duplicate']+df[ 'Damage - Dynamite']+df[ 'Damage - EMP']+df[ 'Damage - Earthshatter']+df['Damage - Fire Strike']+df[ 'Damage - Flashbang']+df[ 'Damage - Focusing Beam']+df[ 'Damage - Focusing Beam - Bonus Damage Only']+df[ 'Damage - Grappling Claw']+df[ 'Damage - Graviton Surge']+df[ 'Damage - Helix Rockets']+df[ 'Damage - Hyperspheres']+df[ 'Damage - Jump Pack']+df[ 'Damage - Meteor Strike']+df[ 'Damage - Micro Missiles']+df[ 'Damage - Minefield']+df[ 'Damage - Molten Core']+df[ 'Damage - Piledriver']+df[ 'Damage - Pistol']+df[ 'Damage - Primal Rage Leap']+df[ 'Damage - Primal Rage Melee']+df[ 'Damage - Primal Rage Total']+df[ 'Damage - Pulse Bomb']+df[ 'Damage - Quick Melee']+df[ 'Damage - RIP-Tire']+df[ 'Damage - Rising Uppercut']+df[ 'Damage - Rocket Punch']+df[ 'Damage - Seismic Slam']+df[ 'Damage - Self Destruct']+df[ 'Damage - Sentry Turret']+df[ 'Damage - Shield Bash']+df[ 'Damage - Sonic']+df[ 'Damage - Steel Trap']+df[ 'Damage - Sticky Bombs']+df[ 'Damage - Storm Arrows']+df[ 'Damage - Swift Strike']+df[ 'Damage - Swift Strike Dragonblade']+df[ 'Damage - Tactical Visor']+df[ 'Damage - Total Mayhem']+df[ 'Damage - Venom Mine']+df[ 'Damage - Weapon']+df[ 'Damage - Weapon Charged']+df[ 'Damage - Weapon Hammer']+df[ 'Damage - Weapon Pistol']+df[ 'Damage - Weapon Primary']+df[ 'Damage - Weapon Recon']+df[ 'Damage - Weapon Scoped']+df[ 'Damage - Weapon Secondary']+df[ 'Damage - Weapon Sentry']+df[ 'Damage - Weapon Tank']+df[ 'Damage - Whole Hog']+df[ 'Damage Absorbed']+df[ 'Damage Amplified']+df[ 'Damage Done']+df['Freeze Spray Damage']+df[ 'Gravitic Flux Damage Done']+df[ 'Hero Damage Done']+df[ 'Icicle Damage']+df[ 'Turret Damage']

# %%
df.head()
# Out:
#    esports_match_id              map_name  ... win         Damage
# 0             30991           Eichenwalde  ...   0  562240.779110
# 1             30991           Eichenwalde  ...   1  628126.701027
# 2             30991                Havana  ...   0  369505.598781
# 3             30991                Havana  ...   1  438383.607557
# 4             30991  Horizon Lunar Colony  ...   0  438116.899123
#
# [5 rows x 364 columns]

# %% [markdown]
# ### Healing 열

# %%
Healing = []
for s in list1:
  if "Heal" in s :
    Healing.append(s)

# %%
print(Healing)
# Out:
# ['Amped Heal Activations', 'Biotic Field Healing Done', 'Biotic Launcher Healing Explosions', 'Biotic Launcher Healing Shots', 'Biotic Orb Healing Efficiency', 'Biotic Orb Maximum Healing', 'Coalescence Healing', 'Coalesence - Healing per Use', 'Heal Song Time Elapsed', 'Healing - Biotic Grenade', 'Healing - Biotic Launcher', 'Healing - Biotic Orb', 'Healing - Coalescence', 'Healing - Harmony Orb', 'Healing - Healing Boost', 'Healing - Healing Boost Amped', 'Healing - Immortality Field', 'Healing - Inspire', 'Healing - Regenerative Burst', 'Healing - Repair Pack', 'Healing - Secondary Fire', 'Healing - Transcendence', 'Healing - Weapon', 'Healing - Weapon Scoped', 'Healing - Weapon Valkyrie', 'Healing Accuracy', 'Healing Amplified', 'Healing Done', 'Healing Received', 'Health Recovered', 'Self Healing', 'Self Healing Percent of Damage Taken', 'Transcendence Healing', 'Transcendence Percent of Healing', 'Valkyrie Healing Efficiency']

# %%
len(Healing)
# Out:
# 35

# %%
df['Healing'] = df['Amped Heal Activations'] + df['Biotic Field Healing Done'] + df['Biotic Launcher Healing Explosions'] + df['Biotic Launcher Healing Shots'] + df['Biotic Orb Healing Efficiency'] + df['Biotic Orb Maximum Healing'] + df['Coalescence Healing'] + df['Coalesence - Healing per Use'] + df[ 'Heal Song Time Elapsed'] + df[ 'Healing - Biotic Grenade'] + df[ 'Healing - Biotic Launcher'] + df[ 'Healing - Biotic Orb'] + df[ 'Healing - Coalescence'] + df[ 'Healing - Harmony Orb'] + df[ 'Healing - Healing Boost'] + df[ 'Healing - Healing Boost Amped'] + df[ 'Healing - Immortality Field'] + df[ 'Healing - Inspire'] + df[ 'Healing - Regenerative Burst'] + df[ 'Healing - Repair Pack'] + df[ 'Healing - Secondary Fire'] + df[ 'Healing - Transcendence'] + df[ 'Healing - Weapon'] + df[ 'Healing - Weapon Scoped'] + df[ 'Healing - Weapon Valkyrie'] + df[ 'Healing Accuracy'] + df[ 'Healing Amplified'] + df[ 'Healing Done'] +  df[ 'Health Recovered'] + df[ 'Self Healing'] + df[ 'Self Healing Percent of Damage Taken'] + df[ 'Transcendence Healing'] + df[ 'Transcendence Percent of Healing'] + df[ 'Valkyrie Healing Efficiency']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2282 entries, 0 to 2281
# Columns: 368 entries, esports_match_id to Barrier
# dtypes: float64(365), int64(1), object(2)
# memory usage: 6.4+ MB

# %%
df.head()
# Out:
#    esports_match_id              map_name  ...         Damage        Healing
# 0             30991           Eichenwalde  ...  562240.779110  102994.122865
# 1             30991           Eichenwalde  ...  628126.701027  119825.020513
# 2             30991                Havana  ...  369505.598781   69563.366620
# 3             30991                Havana  ...  438383.607557   78776.610181
# 4             30991  Horizon Lunar Colony  ...  438116.899123   90377.982786
#
# [5 rows x 365 columns]

# %% [markdown]
# ### Kill 열

# %%
Kill = []

for s in list1:
  if "Kill" in s:
    Kill.append(s)

# %%
print(Kill)
# Out:
# ['Accretion Kills', 'Barrage Kills', 'Biotic Grenade Kills', 'Blaster Kills', 'Blizzard Kills', 'Bob Kills', 'Charge Kills', 'Coach Gun Kills', 'Coalescence Kills', 'Concussion Mine Kills', 'Critical Hit Kills', 'Deadeye Kills', 'Death Blossom Kills', 'Deflection Kills', 'Dragonblade Kills', 'Dragonstrike Kills', 'Duplicate Kills', 'Dynamite Kills', 'Earthshatter Kills', 'Environmental Kills', 'Fan the Hammer Kills', 'Fire Strike Kills', 'Focusing Beam Kills', 'Grappling Claw Kills', 'Gravitic Flux Kills', 'Graviton Surge Kills', 'Hammer Kills', 'Helix Rocket Kills', 'High Energy Kills', 'Jump Pack Kills', 'Knockback Kills', 'Melee Kills', 'Meteor Strike Kills', 'Minefield Kills', 'Molten Core Kills', 'Objective Kills', 'Overload Kills', 'Photon Projector Kills', 'Piledriver Kills', 'Primal Rage Kills', 'Pulse Bomb Kills', 'RIP-Tire Kills', 'Recon Kills', 'Scoped Critical Hit Kills', 'Self-Destruct Kills', 'Sentry Kills', 'Sentry Turret Kills', 'Solo Kills', 'Soundwave Kills', 'Stick
# ...

# %%
len(Kill)
# Out:
# 59

# %%
df['Kill'] = df['Accretion Kills'] + df['Barrage Kills'] + df[ 'Biotic Grenade Kills'] + df[ 'Blaster Kills'] + df[ 'Blizzard Kills'] + df[ 'Bob Kills'] + df[ 'Charge Kills'] + df[ 'Coach Gun Kills'] + df[ 'Coalescence Kills'] + df[ 'Concussion Mine Kills'] + df[ 'Critical Hit Kills'] + df[ 'Deadeye Kills'] + df[ 'Death Blossom Kills'] + df[ 'Deflection Kills'] + df[ 'Dragonblade Kills'] + df[ 'Dragonstrike Kills'] + df[ 'Duplicate Kills'] + df[ 'Dynamite Kills'] + df[ 'Earthshatter Kills'] + df[ 'Environmental Kills'] + df[ 'Fan the Hammer Kills'] + df[ 'Fire Strike Kills'] + df[ 'Focusing Beam Kills'] + df[ 'Grappling Claw Kills'] + df[ 'Gravitic Flux Kills'] + df[ 'Graviton Surge Kills'] + df[ 'Hammer Kills'] + df['Helix Rocket Kills'] + df[ 'High Energy Kills'] + df[ 'Jump Pack Kills'] + df[ 'Knockback Kills'] + df[ 'Melee Kills'] + df[ 'Meteor Strike Kills'] + df[ 'Minefield Kills'] + df[ 'Molten Core Kills'] + df[ 'Objective Kills'] + df[ 'Overload Kills'] + df[ 'Photon Projector Kills'] + df[ 'Piledriver Kills'] + df[ 'Primal Rage Kills'] + df[ 'Pulse Bomb Kills'] + df[ 'RIP-Tire Kills'] + df[ 'Recon Kills'] + df[ 'Scoped Critical Hit Kills'] + df[ 'Self-Destruct Kills'] + df[ 'Sentry Kills'] + df[ 'Sentry Turret Kills'] + df[ 'Solo Kills'] + df[ 'Soundwave Kills'] + df[ 'Sticky Bombs Kills'] + df[ 'Storm Arrow Kills'] + df[ 'Tactical Visor Kills'] + df[ 'Tank Kills'] + df[ 'Torbjörn Kills'] + df[ 'Total Mayhem Kills'] + df[ 'Turret Kills'] + df[ 'Venom Mine Kills'] + df[ 'Weapon Kills'] + df[ 'Whole Hog Kills'] + df['Multikills']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2282 entries, 0 to 2281
# Columns: 366 entries, esports_match_id to Kill
# dtypes: float64(363), int64(1), object(2)
# memory usage: 6.4+ MB

# %%
df.tail()
# Out:
#       esports_match_id          map_name  ...       Healing   Kill
# 2241             35554             Busan  ...  56502.792803  120.0
# 2242             35554        King's Row  ...  69035.384789  110.0
# 2243             35554        King's Row  ...  70345.821365  171.0
# 2244             35554  Temple of Anubis  ...  62284.157168  136.0
# 2245             35554  Temple of Anubis  ...  53357.051466  216.0
#
# [5 rows x 366 columns]

# %%
for s in list1:
  if "kill" in s:
    Kill.append(s)

# %%
len(Kill)
# Out:
# 61

# %%
print(Kill)
# Out:
# ['Accretion Kills', 'Barrage Kills', 'Biotic Grenade Kills', 'Blaster Kills', 'Blizzard Kills', 'Bob Kills', 'Charge Kills', 'Coach Gun Kills', 'Coalescence Kills', 'Concussion Mine Kills', 'Critical Hit Kills', 'Deadeye Kills', 'Death Blossom Kills', 'Deflection Kills', 'Dragonblade Kills', 'Dragonstrike Kills', 'Duplicate Kills', 'Dynamite Kills', 'Earthshatter Kills', 'Environmental Kills', 'Fan the Hammer Kills', 'Fire Strike Kills', 'Focusing Beam Kills', 'Grappling Claw Kills', 'Gravitic Flux Kills', 'Graviton Surge Kills', 'Hammer Kills', 'Helix Rocket Kills', 'High Energy Kills', 'Jump Pack Kills', 'Knockback Kills', 'Melee Kills', 'Meteor Strike Kills', 'Minefield Kills', 'Molten Core Kills', 'Objective Kills', 'Overload Kills', 'Photon Projector Kills', 'Piledriver Kills', 'Primal Rage Kills', 'Pulse Bomb Kills', 'RIP-Tire Kills', 'Recon Kills', 'Scoped Critical Hit Kills', 'Self-Destruct Kills', 'Sentry Kills', 'Sentry Turret Kills', 'Solo Kills', 'Soundwave Kills', 'Stick
# ...

# %% [markdown]
# ### Death 열

# %%
df['Death'] = df["Deaths"] + df["Environmental Deaths"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2282 entries, 0 to 2281
# Columns: 367 entries, esports_match_id to Death
# dtypes: float64(364), int64(1), object(2)
# memory usage: 6.4+ MB

# %%
df.head()
# Out:
#    esports_match_id              map_name  ...   Kill  Death
# 0             30991           Eichenwalde  ...  210.0  106.0
# 1             30991           Eichenwalde  ...  313.0  102.0
# 2             30991                Havana  ...  138.0  118.0
# 3             30991                Havana  ...  337.0   60.0
# 4             30991  Horizon Lunar Colony  ...  207.0   92.0
#
# [5 rows x 367 columns]

# %% [markdown]
# ### Barrier열

# %%
Barrier = []
for s in list1:
  if "Barrier" in s:
    Barrier.append(s)

# %%
print(Barrier)
# Out:
# ['Barrier Damage Done', 'Projected Barrier Damage Blocked', 'Projected Barriers Applied', 'Sound Barrier Casts', 'Sound Barrier Efficiency', 'Sound Barriers Provided']

# %%
df['Barrier'] = df['Barrier Damage Done']+df['Projected Barrier Damage Blocked']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2282 entries, 0 to 2281
# Columns: 368 entries, esports_match_id to Barrier
# dtypes: float64(365), int64(1), object(2)
# memory usage: 6.4+ MB

# %%
df.head()
# Out:
#    esports_match_id              map_name  ...  Death       Barrier
# 0             30991           Eichenwalde  ...  106.0   93901.40980
# 1             30991           Eichenwalde  ...  102.0  143348.93450
# 2             30991                Havana  ...  118.0   49429.29399
# 3             30991                Havana  ...   60.0   88845.75709
# 4             30991  Horizon Lunar Colony  ...   92.0   57440.94655
#
# [5 rows x 368 columns]

# %% [markdown]
# ### Assist열

# %%
Assist = []
for s in list1:
  if "Assist" in s:
    Assist.append(s)

# %%
print(Assist)
# Out:
# ['Amplification Matrix Assists', 'Assists', 'Defensive Assists', 'Nano Boost Assists', 'Offensive Assists', 'Recon Assists', 'Supercharger Assists']

# %% [markdown]
# * 확인 결과 Assist열은 Asssits로 대체
#
#   - Defensive Assists
#   - Offensive Assists
#   -> 공격형 지원이랑 방어형 지원이기 때문에 따로 나눌 필요없이 둘다 피쳐로 써도 좋을듯

# %% [markdown]
# ## 데이터 슬라이싱

# %%
df_final = df.loc[:,[	'esports_match_id',	'map_name',	'team_name', 'win', 'Damage', 'Healing', 'Kill', 'Death', 'Barrier', 'Eliminations', 'Final Blows', 'Healing Received', 'Damage Blocked', 'Damage Taken', 'Ultimates Earned - Fractional', 'Ultimates Negated', 'Ultimates Used', 'Assists', 'Defensive Assists', 'Offensive Assists', 'Time Played'  ]]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246 entries, 0 to 2245
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   esports_match_id               2246 non-null   int64
#  1   map_name                       2246 non-null   object
#  2   team_name                      2246 non-null   object
#  3   win                            2246 non-null   int64
#  4   Damage                         2246 non-null   float64
#  5   Healing                        2246 non-null   float64
#  6   Kill                           2246 non-null   float64
#  7   Death                          2246 non-null   float64
#  8   Barrier                        2246 non-null   float64
#  9   Eliminations                   2246 non-null   int64
#  10  Final Blows                    2246 non-null   int64
#  11  Healing Received               2246 non-null   float64
# ...

# %%
df_final.head()
# Out:
#    esports_match_id              map_name  ... Offensive Assists   Time Played
# 0             30991           Eichenwalde  ...              86.0  11785.838170
# 1             30991           Eichenwalde  ...             114.0  11785.838170
# 2             30991                Havana  ...              62.0   8631.732713
# 3             30991                Havana  ...              98.0   8631.732713
# 4             30991  Horizon Lunar Colony  ...             114.0   9881.643794
#
# [5 rows x 21 columns]

# %% [markdown]
# * 위의 df_fianl csv로 내보내기

# %%
df_final.to_csv('df_final2.csv')
